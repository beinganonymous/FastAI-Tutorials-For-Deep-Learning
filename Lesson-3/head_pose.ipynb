# %% [markdown]
# #Regression with BIWI head pose dataset
# Here we create custom dataset using regression on images. Our task is to find the center of the head in each image. We can take data from [BIWI head pose dataset](https://data.vision.ee.ethz.ch/cvl/gfanelli/head_pose/head_forest.html#db).

# %% [markdown]
# Mount my Google Drive
#
# * For backup
# * For storage
# * For file transfer

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir="/content/gdrive/My drive"
base_dir=root_dir+"fastai-v3"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %% [markdown]
# Import some libraries and modules for performing some operation and matplotlib for plotting the graph

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *

# %% [markdown]
# #Getting and converting the data

# %% [markdown]
# Load the dataset and store it in one variable

# %%
path = untar_data(URLs.BIWI_HEAD_POSE)

# %% [markdown]
# Here we have to read calibration number which is provided in file called rgb.cal

# %%
cal = np.genfromtxt(path/'01'/'rgb.cal', skip_footer=6); cal
# Out:
# array([[517.679,   0.   , 320.   ],
#        [  0.   , 517.679, 240.5  ],
#        [  0.   ,   0.   ,   1.   ]])

# %%
fname = '09/frame_00667_rgb.jpg'

# %%
def img2txt_name(f): return path/f'{str(f)[:-7]}pose.txt'

# %%
img = open_image(path/fname)
img.show()

# %%
ctr = np.genfromtxt(img2txt_name(fname), skip_header=3); ctr
# Out:
# array([187.332 ,  40.3892, 893.135 ])

# %% [markdown]
# Here we use uction called convert_biwi which is used to take their co-ordinates change through depth sensor calibration numbers to end up with actual center co-ordinate. It is nothing to do with deep learning.

# %%
def convert_biwi(coords):
    c1 = coords[0] * cal[0][0]/coords[2] + cal[0][2]
    c2 = coords[1] * cal[1][1]/coords[2] + cal[1][2]
    return tensor([c2,c1])

def get_ctr(f):
    ctr = np.genfromtxt(img2txt_name(f), skip_header=3)
    return convert_biwi(ctr)

def get_ip(img,pts): return ImagePoints(FlowField(img.size, pts), scale=True)

# %%
get_ctr(fname)
# Out:
# tensor([263.9104, 428.5814])

# %%
ctr = get_ctr(fname)
img.show(y=get_ip(img, ctr), figsize=(6, 6))

# %% [markdown]
# #Creating a dataset

# %%
data = (PointsItemList.from_folder(path)
        .split_by_valid_func(lambda o: o.parent.name=='13')
        .label_from_func(get_ctr)
        .transform(get_transforms(), tfm_y=True, size=(120,160))
        .databunch().normalize(imagenet_stats)
       )

# %%
data.show_batch(3, figsize=(9,6))

# %% [markdown]
# #Train model

# %%
learn = cnn_learner(data, models.resnet34)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:01<00:00, 43784877.46it/s]

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 2e-2

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.046539</td>
#       <td>0.003017</td>
#       <td>02:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.016389</td>
#       <td>0.003383</td>
#       <td>02:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.008062</td>
#       <td>0.005060</td>
#       <td>02:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.005100</td>
#       <td>0.001251</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.003690</td>
#       <td>0.000780</td>
#       <td>02:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results()

# %% [markdown]
# #Data augmentation

# %%
tfms = get_transforms(max_rotate=20, max_zoom=1.5, max_lighting=0.5, max_warp=0.4, p_affine=1., p_lighting=1.)

data = (PointsItemList.from_folder(path)
        .split_by_valid_func(lambda o: o.parent.name=='13')
        .label_from_func(get_ctr)
        .transform(tfms, tfm_y=True, size=(120,160))
        .databunch().normalize(imagenet_stats)
       )

# %%
def _plot(i,j,ax):
    x,y = data.train_ds[0]
    x.show(ax, y=y)

plot_multi(_plot, 3, 3, figsize=(8,6))
